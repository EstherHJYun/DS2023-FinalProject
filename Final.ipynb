# %% [markdown]
# # The Human Cost of Innovation

# %% [markdown]
# ### Final product

# %% [markdown]
# ![](attachment:7b0617e1-3d00-4714-b6d3-961d022e4bad.png)

# %% [markdown]
# <center>
# This infographic aims to convey to the audience that mental health challenges are evident in the technology industry and urges companies to respond by creating a stigma-free workplace and providing meaningful resources.
# </center>

# %% [markdown]
# ### Resources

# %% [markdown]
# Column names:

# %%
import pandas as pd
df = pd.read_csv("data.csv")
column_names = pd.DataFrame(df.columns, columns=["Column Name"])
column_names
# Out:
#                Column Name
# 0             tech_company
# 1                 benefits
# 2      workplace_resources
# 3   mh_employer_discussion
# 4   mh_coworker_discussion
# 5         medical_coverage
# 6            mental_health
# 7                 mh_share
# 8                      age
# 9                   gender
# 10                 country

# %% [markdown]
# Link to data file:

# %% [markdown]
# https://data.mendeley.com/datasets/mmnzx4w8cg/1

# %% [markdown]
# Jupyter Notebooks:

# %% [markdown]
# [Part 1] (https://github.com/EstherHJYun/DS2023-FinalProject/blob/main/1.ipynb)

# %% [markdown]
# [Part 2] (https://github.com/EstherHJYun/DS2023-FinalProject/blob/main/2.ipynb)

# %% [markdown]
# [Part 3] (https://github.com/EstherHJYun/DS2023-FinalProject/blob/main/3.ipynb)
